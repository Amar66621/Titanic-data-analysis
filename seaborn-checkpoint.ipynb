# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns

# %%
df=pd.read_csv('titanic_dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.histplot(df['Age'],kde=True)
# Out:
# C:\Users\amarjeet\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\amarjeet\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df['Age'],kde=True,color='r')
# Out:
# C:\Users\amarjeet\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\amarjeet\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.displot(df['Age'],kde=True)
# Out:
# C:\Users\amarjeet\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\amarjeet\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.lineplot(y=df['Age'],x=df['Name'])
# Out:
# C:\Users\amarjeet\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\amarjeet\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\amarjeet\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df=pd.read_excel('Covid cases in India.xlsx')

# %%
df.head()
# Out:
#    S. No. Name of State / UT  Total Confirmed cases (Indian National)  \
# 0       1     Andhra Pradesh                                       12
# 1       2       Chhattisgarh                                        6
# 2       3              Delhi                                       38
# 3       4            Gujarat                                       43
# 4       5            Haryana                                       16
#
#    Total Confirmed cases ( Foreign National )  Cured  Death
# 0                                           0      1      0
# 1                                           0      0      0
# 2                                           1      6      1
# 3                                           0      0      3
# 4                                          14     11      0

# %%
df.shape
# Out:
# (26, 6)

# %%
df.describe()
# Out:
#           S. No.  Total Confirmed cases (Indian National)  \
# count  26.000000                                26.000000
# mean   13.500000                                26.423077
# std     7.648529                                35.586709
# min     1.000000                                 1.000000
# 25%     7.250000                                 6.000000
# 50%    13.500000                                14.500000
# 75%    19.750000                                33.500000
# max    26.000000                               144.000000
#
#        Total Confirmed cases ( Foreign National )      Cured      Death
# count                                   26.000000  26.000000  26.000000
# mean                                     1.615385   2.461538   0.653846
# std                                      3.589729   4.420233   1.017539
# min                                      0.000000   0.000000   0.000000
# 25%                                      0.000000   0.000000   0.000000
# ...

# %%
df.set_index('S. No.', inplace=True)

# %%
df
# Out:
#        Name of State / UT  Total Confirmed cases (Indian National)  \
# S. No.
# 1          Andhra Pradesh                                       12
# 2            Chhattisgarh                                        6
# 3                   Delhi                                       38
# 4                 Gujarat                                       43
# 5                 Haryana                                       16
# 6        Himachal Pradesh                                        4
# 7               Karnataka                                       20
# 8                  Kerala                                      131
# 9          Madhya Pradesh                                       23
# 10            Maharashtra                                      144
# 11                 Odisha                                        3
# 12             Puducherry                                        1
# 13                 Punjab                                       29
# ...

# %%
df.describe()
# Out:
#        Total Confirmed cases (Indian National)  \
# count                                26.000000
# mean                                 26.423077
# std                                  35.586709
# min                                   1.000000
# 25%                                   6.000000
# 50%                                  14.500000
# 75%                                  33.500000
# max                                 144.000000
#
#        Total Confirmed cases ( Foreign National )      Cured      Death
# count                                   26.000000  26.000000  26.000000
# mean                                     1.615385   2.461538   0.653846
# std                                      3.589729   4.420233   1.017539
# min                                      0.000000   0.000000   0.000000
# 25%                                      0.000000   0.000000   0.000000
# 50%                                      0.000000   0.000000   0.000000
# ...

# %%
df.head()
# Out:
#        Name of State / UT  Total Confirmed cases (Indian National)  \
# S. No.
# 1          Andhra Pradesh                                       12
# 2            Chhattisgarh                                        6
# 3                   Delhi                                       38
# 4                 Gujarat                                       43
# 5                 Haryana                                       16
#
#         Total Confirmed cases ( Foreign National )  Cured  Death
# S. No.
# 1                                                0      1      0
# 2                                                0      0      0
# 3                                                1      6      1
# 4                                                0      0      3
# 5                                               14     11      0

# %%
df['Total_cases']=df['Total Confirmed cases (Indian National)'] + df['Total Confirmed cases ( Foreign National )']

# %%
df["Total_cases"]
# Out:
# S. No.
# 1      12
# 2       6
# 3      39
# 4      43
# 5      30
# 6       4
# 7      20
# 8     138
# 9      23
# 10    147
# 11      3
# 12      1
# 13     29
# 14     43
# 15     35
# 16     45
# 17      7
# 18     18
# 19     13
# 20     43
# 21      4
# 22     11
# 23      7
# 24      1
# 25      6
# 26      1
# Name: Total_cases, dtype: int64

# %%
df['Total_cases'].sum()
# Out:
# 729

# %%
df.head()
# Out:
#        Name of State / UT  Total Confirmed cases (Indian National)  \
# S. No.
# 1          Andhra Pradesh                                       12
# 2            Chhattisgarh                                        6
# 3                   Delhi                                       38
# 4                 Gujarat                                       43
# 5                 Haryana                                       16
#
#         Total Confirmed cases ( Foreign National )  Cured  Death  Total_cases
# S. No.
# 1                                                0      1      0           12
# 2                                                0      0      0            6
# 3                                                1      6      1           39
# 4                                                0      0      3           43
# 5                                               14     11      0           30

# %%
#active casee
df['Total_active']=df['Total_cases']-(df['Cured']+df['Death'])

# %%
df
# Out:
#        Name of State / UT  Total Confirmed cases (Indian National)  \
# S. No.
# 1          Andhra Pradesh                                       12
# 2            Chhattisgarh                                        6
# 3                   Delhi                                       38
# 4                 Gujarat                                       43
# 5                 Haryana                                       16
# 6        Himachal Pradesh                                        4
# 7               Karnataka                                       20
# 8                  Kerala                                      131
# 9          Madhya Pradesh                                       23
# 10            Maharashtra                                      144
# 11                 Odisha                                        3
# 12             Puducherry                                        1
# 13                 Punjab                                       29
# ...

# %%
df["Total_active"].sum()
# Out:
# 648

# %%
df1=df[['Name of State / UT','Total_cases','Cured','Death','Total_active']]

# %%
df1.head()
# Out:
#        Name of State / UT  Total_cases  Cured  Death  Total_active
# S. No.
# 1          Andhra Pradesh           12      1      0            11
# 2            Chhattisgarh            6      0      0             6
# 3                   Delhi           39      6      1            32
# 4                 Gujarat           43      0      3            40
# 5                 Haryana           30     11      0            19

# %%
sns.barplot(y='Name of State / UT',x='Total_cases',data=df1)
# Out:
# C:\Users\amarjeet\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\amarjeet\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\amarjeet\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Total_cases', ylabel='Name of State / UT'>
